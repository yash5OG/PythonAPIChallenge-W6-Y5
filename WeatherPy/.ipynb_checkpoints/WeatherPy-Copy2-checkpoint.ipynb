# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#!pip3 install citipy
# Out:
# ...
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559700 sha256=0556c37b30e5af566e43407247031d9ba7f955121b69693162c7d7218ac2f817
#   Stored in directory: c:\users\ystil\appdata\local\pip\cache\wheels\6d\df\5e\ad8eb9cc5ee7f4ba76865167c09f9a7edff405c669111d8353
# Successfully built citipy
# ...

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities #printed to check cities
# Out:
# ['kodiak',
#  'cockburn town',
#  'udachnyy',
#  'belushya guba',
#  'punta arenas',
#  'provideniya',
#  'meulaboh',
#  'el retorno',
#  'varhaug',
#  'karaul',
#  'mehamn',
#  'san cristobal',
#  'masallatah',
#  'new norfolk',
#  'hilo',
#  'tasiilaq',
#  'butaritari',
#  'illoqqortoormiut',
#  'gigmoto',
#  'dalby',
#  'maues',
#  'olafsvik',
#  'yellowknife',
#  'albany',
#  'rikitea',
#  'cherskiy',
#  'ribeira grande',
#  'severo-kurilsk',
#  'vaitupu',
#  'atuona',
#  'sena madureira',
#  'sao filipe',
#  'cao bang',
#  'grindavik',
#  'barrow',
#  'qaanaaq',
#  'evanston',
#  'mar del plata',
#  'coihueco',
#  'bluff',
#  'busselton',
#  'barraute',
#  'attawapiskat',
#  'ocos',
#  'hofn',
#  'iqaluit',
#  'ushuaia',
#  'vyartsilya',
#  'russkaya polyana',
#  'marcona',
#  'rungata',
#  'muros',
#  'hamilton',
#  'benguela',
#  'sitka',
#  'ancud',
#  'banda aceh',
#  'narsaq',
#  'lebu',
#  'ouango',
#  'bredasdorp',
#  'marchena',
#  'upernavik',
#  'markova',
# ...

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=9e04adce039f8575940ab491cb24b547&units=imperial&q='

# %%
# set up lists to hold reponse info
lat = []
lon = []
temp = []
maxtemp = []
humidity = []
windspeed = []
winddeg = []
date = []
country = []
cloudiness = []
sunset = []
sunrise = []
visibility = []




# Loop through the list of cities and perform a request for data on each
print("Beginning Data Retrieval")
print("-"*69)
i = 0
j = 1
for n, city in enumerate(cities):
    i = i + 1
    if i == 51:
        i = 1
        j = j + 1
        time.sleep(6.9)
    print(f"Processing Record {i} of Set {j} | {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        maxtemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        windspeed.append(response['wind']['speed'])
        winddeg.append(response['wind']['deg'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
        sunrise.append(response['sys']['sunrise'])
        sunset.append(response['sys']['sunset'])
        visibility.append(response['visibility'])
    except KeyError:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lon.append(np.nan)
        temp.append(np.nan)
        maxtemp.append(np.nan)
        humidity.append(np.nan)
        windspeed.append(np.nan)
        winddeg.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)
        sunrise.append(np.nan)
        sunset.append(np.nan)
        visibility.append(np.nan)
print("-"*69)
print("Data Retrieval Complete")
print("-"*69)
# Out:
# Beginning Data Retrieval
# ---------------------------------------------------------------------
# Processing Record 1 of Set 1 | provideniya
# Processing Record 2 of Set 1 | inirida
# Processing Record 3 of Set 1 | gannan
# Processing Record 4 of Set 1 | yulara
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | pisco
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | cherskiy
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | georgetown
# Processing Record 13 of Set 1 | hambantota
# Processing Record 14 of Set 1 | santa lucia
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | tiksi
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | fort nelson
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | upernavik
# ...

# %%
len(maxtemp)
# Out:
# 619

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | touba
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | rio grande
# Processing Record 7 of Set 1 | ibra
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | nemuro
# Processing Record 12 of Set 1 | morgan city
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | kawalu
# Processing Record 15 of Set 1 | hami
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | hjallerup
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | victoria
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %%
print(len(lat), len(lon), len(temp), len(maxtemp), len(humidity), len(windspeed), len(winddeg), len(date), len(country), len(cloudiness),len(sunset),len(sunrise), len(visibility))
# Out:
# 619 619 619 619 619 619 619 619 619 619 619 619 619

# %%
# to dataframe.
weatherdf = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": maxtemp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": windspeed,
    "Country": country,
    "Date": date,
    "Wind deg" : winddeg,
    "Sunrise" : sunrise,
    "Sunset" : sunset,
    "Visibility" : visibility,
    "Temp" : temp
})

# %%
weatherdf.count()
# Out:
# City          619
# Lat           559
# Lng           559
# Max Temp      559
# Humidity      559
# Cloudiness    559
# Wind Speed    559
# Country       559
# Date          559
# Wind deg      559
# Sunrise       559
# Sunset        559
# Visibility    559
# Temp          559
# dtype: int64

# %%
# Drop NaN
weatherdf = weatherdf.dropna(how="any")
print(weatherdf.count())
# Out:
# City          559
# Lat           559
# Lng           559
# Max Temp      559
# Humidity      559
# Cloudiness    559
# Wind Speed    559
# Country       559
# Date          559
# Wind deg      559
# Sunrise       559
# Sunset        559
# Visibility    559
# Temp          559
# dtype: int64

# %%
# Export the city data into a .csv file.
weatherdf.to_csv("./output_data/cityweatherdata.csv", index=False)

# %%
# Display the DataFrame
weatherdf1 = pd.read_csv("./output_data/cityweatherdata.csv")

weatherdf1.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   provideniya  64.3833 -173.3000    -13.23      83.0        99.0
# 1       inirida   3.8653  -67.9239     93.69      42.0       100.0
# 2        gannan  47.9147  123.5031    -12.14      89.0       100.0
# 3        yulara -25.2406  130.9889     84.20      37.0        40.0
# 4  puerto ayora  -0.7393  -90.3518     86.00      66.0         0.0
#
#    Wind Speed Country          Date  Wind deg       Sunrise        Sunset  \
# 0        7.67      RU  1.612035e+09      58.0  1.612124e+09  1.612149e+09
# 1        2.80      CO  1.612035e+09      24.0  1.612004e+09  1.612047e+09
# 2        3.40      CN  1.612035e+09     131.0  1.612049e+09  1.612083e+09
# 3       12.66      AU  1.612035e+09     100.0  1.612040e+09  1.612088e+09
# 4       16.11      EC  1.612035e+09     130.0  1.612009e+09  1.612052e+09
#
#    Visibility   Temp
# 0     10000.0 -13.23
# 1     10000.0  93.69
# 2     10000.0 -12.14
# 3     10000.0  84.20
# ...

# %%
weatherdf1.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  559.000000  559.000000  559.000000  559.000000  559.000000  559.000000
# mean    19.266063   19.842802   49.885259   73.008945   53.411449    8.542415
# std     32.839844   89.959321   33.331529   19.689933   40.203411    6.105638
# min    -54.800000 -175.200000  -50.170000   10.000000    0.000000    0.310000
# 25%     -6.764550  -60.047900   29.225000   62.000000   11.000000    3.735000
# 50%     22.075200   25.332700   61.030000   77.000000   58.000000    6.930000
# 75%     45.773250  100.868800   77.000000   88.000000   97.000000   11.500000
# max     78.218600  179.316700   96.800000  100.000000  100.000000   37.980000
#
#                Date    Wind deg       Sunrise        Sunset    Visibility  \
# count  5.590000e+02  559.000000  5.590000e+02  5.590000e+02    559.000000
# mean   1.612035e+09  165.726297  1.603364e+09  1.603403e+09   9192.152057
# ...

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
date_time = datetime.date(datetime.now())
date_time
# Out:
# datetime.date(2021, 1, 30)

# %%
date_time = datetime.date(datetime.now())
# Create a scatter plot for latitude vs max temperature.
x_values = weatherdf['Lat']
y_values = weatherdf['Max Temp']
fig1, ax1 = plt.subplots(figsize=(9.69,7.88))
plt.scatter(x_values, y_values,alpha = 0.69, edgecolors = "blue", linewidths = 1.69)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f"City Latitude vs Max Temperature {date_time}")
plt.grid()
plt.savefig("./output_data/latvstemp.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
date_time = datetime.date(datetime.now())
# Create a scatter plot for latitude vs humidity.
x_values = weatherdf['Lat']
y_values = weatherdf['Humidity']
fig1, ax1 = plt.subplots(figsize=(9.69,7.88))
plt.scatter(x_values, y_values,alpha = 0.69, edgecolors = "pink", linewidths = 1.69)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f"City Latitude vs Humidity {date_time}")
plt.grid()
plt.savefig("./output_data/latvshum.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot for latitude vs cloudiness.



date_time = datetime.date(datetime.now())

x_values = weatherdf['Lat']
y_values = weatherdf['Cloudiness']
fig1, ax1 = plt.subplots(figsize=(9.69,7.88))
plt.scatter(x_values, y_values,alpha = 0.69, edgecolors = "cyan", linewidths = 1.69)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"City Latitude vs Cloudiness {date_time}")
plt.grid()
plt.savefig("./output_data/latvscloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
date_time = datetime.date(datetime.now())
# Create a scatter plot for latitude vs max temperature.
x_values = weatherdf['Lat']
y_values = weatherdf['Wind Speed']
fig1, ax1 = plt.subplots(figsize=(9.69,7.88))
plt.scatter(x_values, y_values,alpha = 0.69, edgecolors = "brown", linewidths = 1.69)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f"City Latitude vs Wind Speed {date_time}")
plt.grid()
plt.savefig("./output_data/latvsws.png", bbox_inches="tight")
plt.show()

# %%
df['date'] = pd.to_datetime(df['date'],unit='s')

# %%
weatherdf['Sunset'].head()
# Out:
# 0    1.612149e+09
# 1    1.612047e+09
# 2    1.612083e+09
# 3    1.612088e+09
# 4    1.612052e+09
# Name: Sunset, dtype: float64

# %%
weatherdf1['Sunset'].head()
# Out:
# 0    1.612149e+09
# 1    1.612047e+09
# 2    1.612083e+09
# 3    1.612088e+09
# 4    1.612052e+09
# Name: Sunset, dtype: float64

# %%
weatherdf1['Sunset1'] = pd.to_datetime(weatherdf1['Sunset'],unit='s')

# %%
weatherdf1['Sunset1'].head()
# Out:
# 0   2021-02-01 03:16:19
# 1   2021-01-30 22:43:33
# 2   2021-01-31 08:43:32
# 3   2021-01-31 10:07:19
# 4   2021-01-31 00:19:06
# Name: Sunset1, dtype: datetime64[ns]

# %%
weatherdf1['Sunset2'] = [datetime.time(d) for d in weatherdf1['Sunset1']]

# %%
weatherdf1["Sunset2"].head()
# Out:
# 0    03:16:19
# 1    22:43:33
# 2    08:43:32
# 3    10:07:19
# 4    00:19:06
# Name: Sunset2, dtype: object

# %%
weatherdf1["Sunset3"] = weatherdf1["Sunset2"].astype('str')

# %%
weatherdf1["Sunset3"].head()
# Out:
# 0    03:16:19
# 1    22:43:33
# 2    08:43:32
# 3    10:07:19
# 4    00:19:06
# Name: Sunset3, dtype: object

# %%
df.Geek_ID.str.split('_').str[0]

# %%
weatherdf1["Sunset4"]= weatherdf1.Sunset3.str.split(':').str[0].astype('int')+weatherdf1.Sunset3.str.split(':').str[1].astype('int')/60+weatherdf1.Sunset3.str.split(':').str[2].astype('int')/3600
weatherdf1["Sunset4"].head()
# Out:
# 0     3.271944
# 1    22.725833
# 2     8.725556
# 3    10.121944
# 4     0.318333
# Name: Sunset4, dtype: float64

# %%
date_time = datetime.date(datetime.now())
# Create a scatter plot for latitude vs max temperature.
x_values = weatherdf1['Lat']
y_values = weatherdf1['Sunset4']
fig1, ax1 = plt.subplots(figsize=(9.69,7.88))
plt.scatter(x_values, y_values,alpha = 0.69, edgecolors = "yellow", linewidths = 1.69)
plt.xlabel('Long')
plt.ylabel('Sunset')
plt.title(f"City Latitude vs Sunset {date_time}")
plt.grid()
# plt.savefig("./output_data/latvsSunrise.png", bbox_inches="tight")
plt.show()

# %%
weatherdf.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Wind deg', 'Sunrise', 'Sunset',
#        'Visibility', 'Temp'],
#       dtype='object')

# %%
h = datetime.utcfromtimestamp(weatherdf["Sunrise"][0])
h
# Out:
# datetime.datetime(2021, 1, 29, 18, 17, 27)

# %% [markdown]
# ## Linear Regression

# %%
def regressplot(x_values, y_values, x_label, y_label, hemisphere, line, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    fig1, ax1 = plt.subplots(figsize=(10.69,8.69))
    plt.scatter(x_values, y_values,alpha = 0.69, edgecolors = "r", linewidths = 0.969)
    plt.xlabel(x_label,fontsize = 13)
    plt.ylabel(y_label,fontsize = 13)
    if ylim is not None:
        plt.ylim(0, ylim)
    today = datetime.date(datetime.now())
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label} {today}",fontsize = 13)
  #  plt.annotate(line_eq,xy=(9.69, 50),fontsize=21.55,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
#     plt.annotate(line_eq,xy=(-50, 40),fontsize=21.55,xycoords='data',xytext=(0.4, 0.3), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
#     plt.annotate(line_eq,xy=(9.69, 25),fontsize=21.55,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
# #     # Print r square value
    plt.plot(x_values,regress_values,"r-")
    print(f"The r-squared is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    return line_eq

# %%
def regressplot2(x, y):
    
    
    correlation = st.pearsonr(x,y)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    # Print the answer to above calculation, but squared
    print(f"""The r-squared value is {round((correlation[0]**2),2)}""")

    # Calculate linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Plot linear regression on top of scatter plot
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# %%
northdf = weatherdf.loc[weatherdf["Lat"] >= 0]
southdf = weatherdf.loc[weatherdf["Lat"] < 0]
northdf.head()
southdf.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3         yulara -25.2406  130.9889     84.20      37.0        40.0
# 4   puerto ayora  -0.7393  -90.3518     86.00      66.0         0.0
# 5          pisco -13.7000  -76.2167     79.00      65.0         0.0
# 8       hermanus -34.4187   19.2345     66.99      83.0         2.0
# 10  punta arenas -53.1500  -70.9167     59.00      51.0         0.0
#
#     Wind Speed Country          Date  Wind deg       Sunrise        Sunset  \
# 3        12.66      AU  1.612035e+09     100.0  1.612040e+09  1.612088e+09
# 4        16.11      EC  1.612035e+09     130.0  1.612009e+09  1.612052e+09
# 5         6.91      PE  1.612035e+09     270.0  1.612004e+09  1.612050e+09
# 8         1.01      ZA  1.612035e+09     292.0  1.611979e+09  1.612029e+09
# 10       25.32      CL  1.612035e+09     270.0  1.611998e+09  1.612054e+09
#
#     Visibility   Temp
# 3      10000.0  84.20
# 4      10000.0  83.52
# 5      10000.0  77.83
# ...

# %%
def regressplot2(x, y):
    
    
    correlation = st.pearsonr(x,y)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    # Print the answer to above calculation, but squared
    print(f"""The r-squared value is {round((correlation[0]**2),2)}""")

    # Calculate linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Plot linear regression on top of scatter plot
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %%
# Create a scatter plot for latitude vs max temp (northern hemisphere)
x_values = northdf['Lat']
y_values = northdf['Max Temp']
regressplot(x_values, y_values, "Lat", "Max Temp (F)", "Northern",(0, 0))
plt.annotate(line_eq,(10,-10),fontsize=15,color="red")
#plt.savefig("./output_data/Northern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.7480438892847631
# The correlation between both factors is -0.86

# %%
# Call Regression Function and pass appropriate parameters (be sure to run previous cells first
# in order to call the north and south dataframes)
line_eq = regressplot2(x = northdf['Lat'], y = northdf['Max Temp'])

# Annotate linear regression
plt.annotate(line_eq,(10,-10),fontsize=15,color="red")

# Add labels and title to plot
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

#plt.savefig('Output_Files/North_Temp.png')

plt.show()
# Out:
# The correlation between both factors is -0.86
# The r-squared value is 0.75

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %%
# Create a scatter plot for Max Temp vs Lat (southern hemisphere)
x_values = southdf['Lat']
y_values = southdf['Max Temp']
regressplot(x_values, y_values, "Latitude", "Max Temp (F)", "Southern",(-45, 60))
plt.annotate(line_eq,(-50,80),fontsize=15,color="red")
# plt.savefig("./output_data/southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.4459441725682351
# The correlation between both factors is 0.67

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %%
x_values = northdf['Lat']
y_values = northdf['Humidity']
regressplot(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(0, 0))
plt.annotate(line_eq,(50,20),fontsize=15,color="red")
# plt.savefig("./output_data/southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.1136160597618739
# The correlation between both factors is 0.34

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %%
x_values = southdf['Lat']
y_values = southdf['Humidity']
regressplot(x_values, y_values, "Latitude", "Humidity (%)", "Southern",(0, 0))
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
# plt.savefig("./output_data/southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.041648745352471546
# The correlation between both factors is 0.2

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %%
x_values = northdf['Lat']
y_values = northdf['Cloudiness']
regressplot(x_values, y_values, "Latitude", "Cloudiness", "Northern",(0, 0))
plt.annotate(line_eq,(50,20),fontsize=15,color="red")
# plt.savefig("./output_data/southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.09352598023481458
# The correlation between both factors is 0.31

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %%
x_values = southdf['Lat']
y_values = southdf['Cloudiness']
regressplot(x_values, y_values, "Latitude", "Cloudiness", "Southern",(0, 0))
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
# plt.savefig("./output_data/southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.0897215013780772
# The correlation between both factors is 0.3

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %%
x_values = northdf['Lat']
y_values = northdf['Wind Speed']
regressplot(x_values, y_values, "Latitude", "Wind Speed", "Northern",(0, 0))
plt.annotate(line_eq,(50,20),fontsize=15,color="red")
# plt.savefig("./output_data/southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.0005093117780251309
# The correlation between both factors is 0.02

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232

# %%
x_values = southdf['Lat']
y_values = southdf['Wind Speed']
regressplot(x_values, y_values, "Latitude", "Wind Speed", "Southern",(0, 0))
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
# plt.savefig("./output_data/southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.0222259481572764
# The correlation between both factors is -0.15
